# %%
# !pip install pandas
# Out:
# Running cells with 'test-venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/ed/Desktop/Test/test-venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
print("Hello WOrld")
# Out:
# Hello WOrld
